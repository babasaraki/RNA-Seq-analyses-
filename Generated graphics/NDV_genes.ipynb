# %%
import seaborn as sns; 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("NDV_genes.csv")
df
# Out:
#    NDV_genes  Delta_CT Cell_passages
# 0         NP     -5.23     Passage 5
# 1         HN     -2.03     Passage 5
# 2          F     -3.04     Passage 5
# 3         NP     -6.32     Passage 5
# 4         HN     -2.71     Passage 5
# 5          F     -3.63     Passage 5
# 6         NP     -5.01     Passage 5
# 7         HN     -3.23     Passage 5
# 8          F     -3.10     Passage 5
# 9         NP     -7.98    Passage 20
# 10        HN     -5.91    Passage 20
# 11         F      2.67    Passage 20
# 12        NP     -7.20    Passage 20
# 13        HN     -6.52    Passage 20
# 14         F      2.91    Passage 20
# 15        NP     -8.93    Passage 20
# 16        HN     -5.43    Passage 20
# 17         F      3.40    Passage 20

# %%
df.describe
# Out:
# <bound method NDFrame.describe of    NDV_genes  Delta_CT Cell_passages
# 0         NP     -5.23     Passage 5
# 1         HN     -2.03     Passage 5
# 2          F     -3.04     Passage 5
# 3         NP     -6.32     Passage 5
# 4         HN     -2.71     Passage 5
# 5          F     -3.63     Passage 5
# 6         NP     -5.01     Passage 5
# 7         HN     -3.23     Passage 5
# 8          F     -3.10     Passage 5
# 9         NP     -7.98    Passage 20
# 10        HN     -5.91    Passage 20
# 11         F      2.67    Passage 20
# 12        NP     -7.20    Passage 20
# 13        HN     -6.52    Passage 20
# 14         F      2.91    Passage 20
# 15        NP     -8.93    Passage 20
# 16        HN     -5.43    Passage 20
# 17         F      3.40    Passage 20>

# %%
sns.barplot(x='NDV_genes', y='Delta_CT', hue='Cell_passages', data=df)

# %%
sns.barplot(x='NDV_genes', y='Delta_CT', hue='Cell_passages', palette='muted', capsize=0.1, data=df)

# %%
sns.catplot(x='NDV_genes', y='Delta_CT', hue='Cell_passages', kind="violin", data=df)

# %%
sns.catplot(x='NDV_genes', y='Delta_CT', hue='Cell_passages', kind="box", data=df)

# %%
sns.barplot(x='NDV_genes', y='Delta_CT', hue='Cell_passages', palette="Accent", capsize=0.1, data=df)

# %%
sns.barplot(x='NDV_genes', y='Delta_CT', hue='Cell_passages', palette="Accent", capsize=0.1, data=df)
plt.savefig('NDV_genes.png', dpi=300)

# %%
sns.barplot(x='NDV_genes', y='Delta_CT', hue='Cell_passages', palette="Accent", capsize=0.1, data=df)
plt.savefig('NDV_genes.pdf', dpi=300)
