# %%
import seaborn as sns
import numpy as np
import pandas as pd
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("ucc.csv")

# %%
df.describe
# Out:
# <bound method NDFrame.describe of     category  hours_postinfection  viability_percent UCC_cells
# 0        UCC                    0             100.00    TCCSUP
# 1        UCC                    0             100.00      5637
# 2        UCC                    0             100.00    UMUC10
# 3        UCC                    0             100.00     RT112
# 4        UCC                    0             100.00    HT1376
# ..       ...                  ...                ...       ...
# 115      UCC                   96              58.06     RT112
# 116      UCC                   96              66.70    HT1376
# 117      UCC                   96              78.30     SW780
# 118      UCC                   96              48.30     UMUC3
# 119      UCC                   96              42.70      EJ28
#
# [120 rows x 4 columns]>

# %%
sns.lineplot(x="hours_postinfection", y="viability_percent", data=df)

# %%
sns.lineplot(x="hours_postinfection", y="viability_percent", hue="UCC_cells", style="UCC_cells",  
             markers=True, dashes=False, data=df)

# %%
sns.lineplot(x="hours_postinfection", y="viability_percent", hue="UCC_cells",
...    err_style="bars", ci=90, data=df)
