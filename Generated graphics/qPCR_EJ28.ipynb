# %%
import seaborn as sns; sns.set()
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("qPCR EJ28.csv")
df
# Out:
#     Genes        Methods  Fold change (log2R)
# 0  HOXA13  real-time PCR                2.832
# 1  HOXA13  real-time PCR                2.781
# 2  HOXA13  real-time PCR                2.802
# 3  HOXA13        RNA-Seq                2.390
# 4  HOXB13  real-time PCR                3.421
# 5  HOXB13  real-time PCR                3.011
# 6  HOXB13  real-time PCR                3.343
# 7  HOXB13        RNA-Seq               -2.110

# %%
sns.barplot(x='Fold change (log2R)', y='Genes', hue='Methods', data=df)

# %%
sns.barplot(x='Fold change (log2R)', y='Genes', hue='Methods', capsize=0.05, data=df)

# %%
sns.barplot(x='Fold change (log2R)', y='Genes', hue='Methods', 
            palette="rainbow", capsize=0.05, data=df)
